# %% [markdown]
# # Lang Chain

# %% [markdown]
# Langchain is basically use to access OpenAI models.
# Using Langchain, we can use OpenAi models, Hugging Face model and Google model sources.

# %% [markdown]
# ![image.png](attachment:image.png)
