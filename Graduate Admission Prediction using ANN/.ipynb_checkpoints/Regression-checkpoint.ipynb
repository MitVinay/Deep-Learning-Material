# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Admission_Predict_Ver1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.shape
# Out:
# (500, 9)

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df = df.drop('Serial No.', axis = 1)

# %% [markdown]
# ## Architecture
#
# ![image.png](attachment:image.png)

# %%
# Dividing Input and output columns
X = df.drop('Chance of Admit ', axis = 1)
y = df['Chance of Admit ']

# %%
# splitting data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# scaling the values
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() # Because We use it we know the upper and lower bound of the data, like gre maximum can 340

X_train_trf = scaler.fit_transform(X_train)
X_test_trf = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (400, 7)

# %%
model = Sequential()

# First hidden layer so need to mention about the input nodes
model.add(Dense(7,activation='relu',input_dim=7))


# output layer having one perceptron
# linear we are working on regression
model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 7)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             8 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 64 (256.00 B)
#  Trainable params: 64 (256.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# need to mention loss function
# Optimizer : Gradient descent algo : Adam
# loss function : mean_squared_loss
model.compile(optimizer='Adam',loss='mean_squared_error')

# %%
history = model.fit(X_train_trf,y_train,
                    #
                    batch_size=50,
                    epochs=100,
                    verbose=1,
                    # Splitting the data taken into 80 and 20
                    # evalulating performance with 20 percent
                    validation_split=0.2)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5533 - val_loss: 0.5389
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5203 - val_loss: 0.5148
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5036 - val_loss: 0.4913
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4691 - val_loss: 0.4671
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4360 - val_loss: 0.4413
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4255 - val_loss: 0.4137
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3901 - val_loss: 0.3827
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3613 - val_loss: 0.3488
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3307 - val_loss: 0.3113
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2946 - val_loss: 0.2704
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2469 - val_loss: 0.2287
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2088 - val_loss: 0.1873
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1689 - val_loss: 0.1486
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1293 - val_loss: 0.1136
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0984 - val_loss: 0.0828
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0711 - val_loss: 0.0589
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0433 - val_loss: 0.0396
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0270 - val_loss: 0.0266
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0209 - val_loss: 0.0209
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0158 - val_loss: 0.0195
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0169 - val_loss: 0.0193
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0156 - val_loss: 0.0191
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0135 - val_loss: 0.0189
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0152 - val_loss: 0.0187
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0142 - val_loss: 0.0187
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0146 - val_loss: 0.0186
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0147 - val_loss: 0.0185
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0144 - val_loss: 0.0182
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0154 - val_loss: 0.0180
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0147 - val_loss: 0.0177
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0138 - val_loss: 0.0175
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0138 - val_loss: 0.0174
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0134 - val_loss: 0.0173
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0141 - val_loss: 0.0171
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0129 - val_loss: 0.0170
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0127 - val_loss: 0.0168
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126 - val_loss: 0.0166
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0120 - val_loss: 0.0164
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0137 - val_loss: 0.0163
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122 - val_loss: 0.0161
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0127 - val_loss: 0.0159
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0121 - val_loss: 0.0158
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0134 - val_loss: 0.0156
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0138 - val_loss: 0.0155
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - val_loss: 0.0154
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0122 - val_loss: 0.0152
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0108 - val_loss: 0.0151
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122 - val_loss: 0.0149
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - val_loss: 0.0148
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0114 - val_loss: 0.0147
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0115 - val_loss: 0.0146
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0101 - val_loss: 0.0145
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0121 - val_loss: 0.0144
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - val_loss: 0.0142
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0113 - val_loss: 0.0141
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - val_loss: 0.0140
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - val_loss: 0.0139
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0101 - val_loss: 0.0137
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0100 - val_loss: 0.0136
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0105 - val_loss: 0.0136
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - val_loss: 0.0135
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0095 - val_loss: 0.0133
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0100 - val_loss: 0.0132
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100 - val_loss: 0.0131
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0101 - val_loss: 0.0130
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098 - val_loss: 0.0129
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0093 - val_loss: 0.0128
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0095 - val_loss: 0.0127
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0092 - val_loss: 0.0126
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0091 - val_loss: 0.0125
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - val_loss: 0.0124
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0092 - val_loss: 0.0123
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0093 - val_loss: 0.0122
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0098 - val_loss: 0.0121
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0092 - val_loss: 0.0121
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0091 - val_loss: 0.0119
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0086 - val_loss: 0.0119
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0095 - val_loss: 0.0118
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0085 - val_loss: 0.0117
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0090 - val_loss: 0.0116
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0083 - val_loss: 0.0115
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0080 - val_loss: 0.0114
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0082 - val_loss: 0.0114
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0091 - val_loss: 0.0113
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0081 - val_loss: 0.0112
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0076 - val_loss: 0.0111
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0079 - val_loss: 0.0110
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0075 - val_loss: 0.0110
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0087 - val_loss: 0.0109
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0080 - val_loss: 0.0108
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0081 - val_loss: 0.0107
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0078 - val_loss: 0.0106
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0069 - val_loss: 0.0106
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - val_loss: 0.0105
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - val_loss: 0.0104
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - val_loss: 0.0104
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - val_loss: 0.0103
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0065 - val_loss: 0.0102
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0071 - val_loss: 0.0101
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - val_loss: 0.0101

# %%
y_pred = model.predict(X_test_trf)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.48425550588771005

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
